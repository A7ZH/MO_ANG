# %%
import pandas as pd
from ast import literal_eval as make_tuple
import folium
from IPython.display import display

# %%
# !rm -rdf sample_data
# Getting the Data
# !git clone https://github.com/A7ZH/Restaurant_Intelligence.git &> /dev/null
df = pd.read_csv("./Restaurant_Intelligence/UberEats/UberEats_Clean.csv", 
                 encoding='utf-8-sig')
df
# Out:
#                                              Name  ...                        Coordinate
# 0                                      1298 Sushi  ...  (43.8373907, -79.09049809999999)
# 1                                  2 Bros Cuisine  ...               (43.6928, -79.5318)
# 2                                     7 West Cafe  ...         (43.6684707, -79.3867008)
# 3                     7-Eleven (1260 Dundas St W)  ...         (43.6497538, -79.4245662)
# 4           7-Eleven (1718A Wilson Ave @ Dallner)  ...         (43.7204314, -79.5137432)
# ...                                           ...  ...                               ...
# 1425                                 ocean palate  ...         (43.6310385, -79.6264899)
# 1426                         quick munch(steeles)  ...  (43.6622875, -79.35844999999999)
# 1427  z - Shoeless Joe's Sports Grill (Pickering)  ...  (43.8228064, -79.11144589999999)
# 1428                 川渝小馆Red & Hot Szechuan House  ...  (43.84397610000001, -79.3878015)
# 1429                        街边儿 The Chinese Block  ...         (43.7748786, -79.4132928)
#
# [1430 rows x 3 columns]

# %%
cuisine_map = {}
for ind, row in df.iterrows():
  cuisines = row['Cuisine'].split(';')
  coordinate = make_tuple(row['Coordinate'])
  for c in cuisines:
    c = c.lstrip().rstrip()
    if c in cuisine_map:
      cuisine_map[c] += [coordinate] 
    else:
      cuisine_map[c] = [coordinate]

# %%
def plot_cuisine_map(*cuisine_names):
                             # Center of Downtown Toronto
  map = folium.Map(location=[43.653963, -79.387207],
                   tiles='OpenStreetMap',#'cartodbpositron',
                   zoom_start=12)
  for cuisine_name in cuisine_names:
    for coordinate in cuisine_map[cuisine_name]:
      folium.CircleMarker(location=coordinate).add_to(map)
  display(map)

# %%
# Type in any number of cuisines separated by comma
plot_cuisine_map("Indian", "Indian Curry", "Pakistani")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
